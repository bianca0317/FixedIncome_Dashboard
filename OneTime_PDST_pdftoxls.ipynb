# %%
import pandas as pd
import slate3k as slate
import re

# %%
import tabula

# %%
file = "C:/Users/Acer/Desktop/projects/DashboardCreation/PDSTratesPDF/10-2018-PDST-R2-TABLE.pdf"
tables = tabula.read_pdf(file, pages = "all")
tables
# Out:
# [         Date 1M Tag      1M 3M Tag      3M 6M Tag      6M 1Y Tag      1Y  \
#  0   26-Oct-18      B  4.8038      D  4.6433      B  6.1385      D  6.2950
#  1   25-Oct-18      B  4.8286      D  4.6089      D  5.9222      D  6.4203
#  2   24-Oct-18      B  4.9536      D  4.6230      D  5.9480      D  6.4481
#  3   23-Oct-18      D  3.4957      D  4.7488      D  6.0163      D  6.3796
#  4   22-Oct-18      D  3.5269      B  4.9286      D  6.0142      D  6.2177
#  5   19-Oct-18      D  3.5500      B  4.8339      D  5.6072      D  6.2589
#  6   18-Oct-18      B  4.6560      B  4.7783      D  5.7758      D  6.2828
#  7   17-Oct-18      B  4.6638      D  4.0733      D  5.8866      D  6.3043
#  8   16-Oct-18      D  3.6852      D  4.2250      D  5.9507      D  6.2329
#  9   15-Oct-18      D  3.5470      B  5.0964      D  5.5805      D  6.0285
#  10  12-Oct-18      B  4.8231      D  4.4397      D  5.5924      D  5.9980
# ...

# %%
type(tables)
# Out:
# list

# %%
tabula.convert_into("C:/Users/Acer/Desktop/projects/DashboardCreation/PDSTratesPDF/10-2018-PDST-R2-TABLE.pdf", "output2.csv",pages='all', output_format="csv")

# %%
#manually arrange in MS excel from this point
